# %%
//%cflags: -O
//%args:  20
#include <stdio.h>
#include <stdlib.h>
#include <time.h>

void merge(double arr[], int left, int mid, int right);
void mergeSort(double arr[], int left, int right);

int main(int argc, char *argv[]) {
    // Check if the number of arguments is correct
    if (argc != 2) {
        fprintf(stderr, "Usage: %s n\n", argv[0]);
        return 1;
    }

    // Parse the size of the array from the command-line argument
    const int n = atoi(argv[1]);

    // Seed the random number generator
    srand(time(NULL));
    // Generate an array of random doubles
    double *arr=(double*) malloc(n*sizeof(double));//[n];
    for (int i = 0; i < n; i++) {
        arr[i] = (double) rand() / RAND_MAX * 1000.0;
    }
    
    printf("Unsorted array:\n");
    printArray(arr, n);

    // Sort the array using mergeSort()
    printf("Sorting %d values...\n", n);
    clock_t start = clock();
    mergeSort(arr, 0, n-1);
    clock_t end = clock();
    double elapsed = (double) (end - start) / CLOCKS_PER_SEC;

    // Print the sorted data if n is less than 30
    if (n < 30) {
        printf("Sorted data:\n");
        for (int i = 0; i < n; i++) {
            printf("%.2f ", arr[i]);
        }
        printf("\n");
    }

    printf("Sorting took %.4f seconds.\n", elapsed);

    return 0;
}

void merge(double arr[], int left, int mid, int right) {
    int n1 = mid - left + 1;
    int n2 = right - mid;

    // Create temporary arrays
    double L[n1], R[n2];

    // Copy data to temporary arrays
    for (int i = 0; i < n1; i++)
        L[i] = arr[left + i];
    for (int j = 0; j < n2; j++)
        R[j] = arr[mid + 1 + j];

    // Merge the temporary arrays back into arr[left..right]
    int i = 0, j = 0, k = left;
    while (i < n1 && j < n2) {
        if (L[i] <= R[j]) {
            arr[k] = L[i];
            i++;
        } else {
            arr[k] = R[j];
            j++;
        }
        k++;
    }

    // Copy the remaining elements of L[], if there are any
    while (i < n1) {
        arr[k] = L[i];
        i++;
        k++;
    }

    // Copy the remaining elements of R[], if there are any
    while (j < n2) {
        arr[k] = R[j];
        j++;
        k++;
    }
}

void mergeSort(double arr[], int left, int right) {
    if (left < right) {
        int mid = left + (right - left) / 2;

        // Sort first and second halves
        mergeSort(arr, left, mid);
        mergeSort(arr, mid + 1, right);

        // Merge the sorted halves
        merge(arr, left, mid, right);
    }
}

void printArray(double arr[], int n) {
    printf("Array:\n");
    for (int i = 0; i < n; i++) {
        printf("%.2f ", arr[i]);
    }
    printf("\n");
}
# Out:
# /tmp/tmpfssdfhbv.c: In function ‘main’:
# /tmp/tmpfssdfhbv.c:29:5: warning: implicit declaration of function ‘printArray’ [-Wimplicit-function-declaration]
#    29 |     printArray(arr, n);
#       |     ^~~~~~~~~~
# /tmp/tmpfssdfhbv.c: At top level:
# /tmp/tmpfssdfhbv.c:106:6: warning: conflicting types for ‘printArray’
#   106 | void printArray(double arr[], int n) {
#       |      ^~~~~~~~~~
# /tmp/tmpfssdfhbv.c:29:5: note: previous implicit declaration of ‘printArray’ was here
#    29 |     printArray(arr, n);
#       |     ^~~~~~~~~~
# Unsorted array:
# Array:
# 635.45 688.46 316.23 305.86 25.49 986.73 119.31 873.22 675.28 473.14 255.48 229.83 865.57 998.16 711.64 637.90 932.98 331.23 347.04 868.41
# Sorting 20 values...
# Sorted data:
# 25.49 119.31 229.83 255.48 305.86 316.23 331.23 347.04 473.14 635.45 637.90 675.28 688.46 711.64 865.57 868.41 873.22 932.98 986.73 998.16
# Sorting took 0.0000 seconds.
